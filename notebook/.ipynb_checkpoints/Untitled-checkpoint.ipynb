# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
error = np.load('error.npy')
# 绘图
mask = np.where(error>5)
error[mask] = 0
plt.plot(np.arange(error.shape[0]),error)
plt.show()

# %%
np.sum(error)/(error.shape[0]-len(mask[0]))
# Out:
# 6
